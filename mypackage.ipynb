# %%
import numpy as np
from ipywidgets import interact, fixed
from PIL import Image

# %%
    # This is the code we provide
    # or they can add the resize function themselves, to see how one could adapt this
    def imshow(X, resize=None):
        """

        Please enter here a good description.

        """
        @interact
        def _imshow(i:(0, len(X)-1), resize=fixed(resize)):
            im = Image.fromarray(X[i])

            if resize:
                im = im.resize(resize)

            return im

# %%
a_large_array = np.random.randint(0, 256, (20, 256,256,3)).astype(np.uint8)

# %%
imshow(a_large_array, resize=(123,283))
# Out:
# interactive(children=(IntSlider(value=9, description='i', max=19), Output()), _dom_classes=('widget-interact',…
